# %% [markdown]
# ### Define Horizon joglog table

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS core.horizon_joblog (
#     horizon_log_id STRING NOT NULL,
#     target_lakehouse STRING,
#     notebook_name STRING NOT NULL,
#     pipeline_executor STRING NOT NULL,
#     starttime TIMESTAMP,
#     endtime TIMESTAMP,
#     runtime_minutes DOUBLE,
#     run_status STRING,
#     error_message STRING,
#     run_parameteres STRING
# );
